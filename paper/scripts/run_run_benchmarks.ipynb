# %%
RANDOM_SEED = 42
import random, os
import numpy as np
random.seed(RANDOM_SEED)
os.environ['PYTHONHASHSEED'] = str(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

print(f"🔒 Random seed set to {RANDOM_SEED} for reproducibility.")
# Out:
# 🔒 Random seed set to 42 for reproducibility.

# %%
import os
os.environ["GEMINI_API_KEY"] = "YOUR_KEY_HERE"

# %%
# !python paper/scripts/run_benchmarks.py \
  --config paper/config/benchmarks.yaml \
  --repo-root /work \
  --out-results paper/scripts/results \
  --cache-dir paper/scripts/cache/llm_calls \
  --datasets cd8 \
  --seed 42
# Out:
# 2025-12-19 01:48:01,153 INFO:paper.run_benchmarks:=== cd8 ===
# 2025-12-19 01:48:01,153 INFO:paper.run_benchmarks:Loading AnnData: /work/runs/20251201.v1/cd8_benchmark_data.h5ad
# 2025-12-19 01:48:02,832 INFO:paper.run_benchmarks:Computing HVGs (as requested): {'n_top_genes': 2000, 'subset': False, 'batch_key': 'Cancer_Type', 'flavor': 'seurat_v3', 'layer': 'counts'}
# 2025-12-19 01:48:04,309 INFO:paper.run_benchmarks:Computing DE ranks once: groupby=meta.cluster key=de_cache
# 2025-12-19 01:48:09,715 INFO:llm_sc_curator.core:LLM-scCurator initialized with default GeminiBackend (models/gemini-2.5-pro)
# 2025-12-19 01:48:09,716 INFO:llm_sc_curator.core:Global context set: using all 4466 cells (no balanced subsampling).
# 2025-12-19 01:48:09,716 INFO:llm_sc_curator.core:Global context set. Cross-lineage specificity checks enabled.
# 2025-12-19 01:48:09,716 INFO:paper.run_benchmarks:Clusters: 17
# 2025-12-19 01:48:09,718 INFO:paper.run_benchmarks:[1/17] CD8.c01.Tn.MAL (GT=CD8_Naive)
# 2025-12-19 01:48:22,126 INFO:llm_sc_curator.core:Computing global gene_stats for high-Gini rescue...
# 2025-12-19 01:48:24,369 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:48:37,300 INFO:paper.run_benchmarks:[2/17] CD8.c02.Tm.IL7R (GT=CD8_EffectorMemory)
# 2025-12-19 01:48:53,471 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:49:07,956 INFO:paper.run_benchmarks:[3/17] CD8.c03.Tm.RPS12 (GT=CD8_EffectorMemory)
# 2025-12-19 01:49:20,608 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:49:30,985 INFO:paper.run_benchmarks:[4/17] CD8.c04.Tm.CD52 (GT=CD8_EffectorMemory)
# 2025-12-19 01:49:43,337 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:49:55,978 INFO:paper.run_benchmarks:[5/17] CD8.c05.Tem.CXCR5 (GT=CD8_EffectorMemory)
# 2025-12-19 01:50:12,272 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:50:27,316 INFO:paper.run_benchmarks:[6/17] CD8.c06.Tem.GZMK (GT=CD8_EffectorMemory)
# 2025-12-19 01:50:40,698 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:51:00,197 INFO:paper.run_benchmarks:[7/17] CD8.c07.Temra.CX3CR1 (GT=CD8_Effector)
# 2025-12-19 01:51:11,308 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:51:29,627 INFO:paper.run_benchmarks:[8/17] CD8.c08.Tk.TYROBP (GT=CD8_Effector)
# 2025-12-19 01:51:42,428 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:52:02,300 INFO:paper.run_benchmarks:[9/17] CD8.c09.Tk.KIR2DL4 (GT=CD8_Effector)
# 2025-12-19 01:52:15,882 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:52:30,209 INFO:paper.run_benchmarks:[10/17] CD8.c10.Trm.ZNF683 (GT=CD8_EffectorMemory)
# 2025-12-19 01:52:44,525 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:52:56,561 INFO:paper.run_benchmarks:[11/17] CD8.c11.Tex.PDCD1 (GT=CD8_Exhausted)
# 2025-12-19 01:53:06,609 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:53:17,266 INFO:paper.run_benchmarks:[12/17] CD8.c12.Tex.CXCL13 (GT=CD8_Exhausted)
# 2025-12-19 01:53:30,263 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:53:43,040 INFO:paper.run_benchmarks:[13/17] CD8.c13.Tex.myl12a (GT=CD8_Exhausted)
# 2025-12-19 01:53:57,301 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:54:12,323 INFO:paper.run_benchmarks:[14/17] CD8.c14.Tex.TCF7 (GT=CD8_Exhausted)
# 2025-12-19 01:54:26,684 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:54:45,614 INFO:paper.run_benchmarks:[15/17] CD8.c15.ISG.IFIT1 (GT=CD8_ISG)
# 2025-12-19 01:54:57,298 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:55:07,121 INFO:paper.run_benchmarks:[16/17] CD8.c16.MAIT.SLC4A10 (GT=CD8_MAIT)
# 2025-12-19 01:55:18,227 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# 2025-12-19 01:55:31,529 INFO:paper.run_benchmarks:[17/17] CD8.c17.Tm.NME1 (GT=CD8_EffectorMemory)
# 2025-12-19 01:55:54,893 INFO:llm_sc_curator.core:High-Gini rescue: gini >= 0.999 (q=0.9), mean between 0.100 and <= 0.005, selected 0 genes.
# ... storing 'binary_group' as categorical
# /work/paper/scripts/run_benchmarks.py:617: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   "scanpy": getattr(sc, "__version__", ""),
# 2025-12-19 01:56:09,501 INFO:paper.run_benchmarks:Wrote: /work/paper/scripts/results/cd8_benchmark_results_integrated.csv
