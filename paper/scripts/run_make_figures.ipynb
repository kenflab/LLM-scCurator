# %%
# !pwd
# Out:
# /work/paper

# %%
# run commands from the repository root to keep paths consistent.
# %cd /work
# Out:
# /work

# %%
# !ls
# Out:
# CITATION.cff  docker	      llm_sc_curator.egg-info  run.ipynb
# LICENSE       docs	      mkdocs.yml	       run_make_figures.ipynb
# README.md     examples	      paper		       runs
# benchmarks    llm_sc_curator  requirements.txt	       setup.py

# %%
# !python paper/scripts/make_figures.py -help
# Out:
# usage: make_figures.py [-h] [--figure-data-dir FIGURE_DATA_DIR]
#                        [--figdir FIGDIR] [--dataset-order DATASET_ORDER]
#                        [--seed SEED] [--make-fig2a] [--make-confusions]
#                        [--repo-root REPO_ROOT]
#
# options:
#   -h, --help            show this help message and exit
#   --figure-data-dir FIGURE_DATA_DIR
#   --figdir FIGDIR
#   --dataset-order DATASET_ORDER
#   --seed SEED
#   --make-fig2a
#   --make-confusions
#   --repo-root REPO_ROOT
#                         Repo root for importing benchmarks/* configs

# %%
# !python paper/scripts/make_figures.py --make-fig2a --make-confusions
# Out:
# INFO:paper.make_figures:Loading Fig2a-d table: /work/paper/source_data/figure_data/Fig2/Fig2a-d_data.csv
# INFO:fontTools.subset:maxp pruned
# INFO:fontTools.subset:cmap pruned
# INFO:fontTools.subset:kern dropped
# INFO:fontTools.subset:post pruned
# INFO:fontTools.subset:FFTM dropped
# INFO:fontTools.subset:GPOS pruned
# INFO:fontTools.subset:GSUB pruned
# INFO:fontTools.subset:glyf pruned
# INFO:fontTools.subset:Added gid0 to subset
# INFO:fontTools.subset:Added first four glyphs to subset
# INFO:fontTools.subset:Closing glyph list over 'GSUB': 15 glyphs before
# INFO:fontTools.subset:Glyph names: ['.notdef', '.null', 'B', 'C', 'D', 'E', 'M', 'O', 'S', 'U', 'eight', 'four', 'nonmarkingreturn', 'space', 'underscore']
# INFO:fontTools.subset:Glyph IDs:   [0, 1, 2, 3, 23, 27, 37, 38, 39, 40, 48, 50, 54, 56, 66]
# INFO:fontTools.subset:Closed glyph list over 'GSUB': 15 glyphs after
# ...
